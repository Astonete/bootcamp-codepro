# %%
nombre =("Daniel")# variable de tipo string donde se usa para guardar el nombre de una persona
# edad = variable de tipo entero donde se usa para guardar la edad de una persona
edad =123456789101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899100
#ciudad = variable de tipo string donde se usa para guardar la ciudad de una persona
ciudad =("Asunción")

print(nombre)
print(edad)
print(ciudad)

# %%
import this # esto es un easter egg de python, es un poema que describe los principios de diseño de python, es una forma divertida de aprender sobre la filosofía de python y sus características únicas.
# impresion de texto plano en phyton, es una forma básica de mostrar información en la consola, se puede usar para mostrar mensajes, resultados de operaciones, o cualquier tipo de información que se quiera compartir con el usuario.
print("Hola, Mundo! como estas? Todo bien?, espero que si, saludos a todos los programadores del mundo, sigan adelante con sus proyectos y no se rindan nunca, el mundo de la programación es fascinante y lleno de oportunidades, así que sigan aprendiendo y creciendo cada día. ¡Mucho éxito en sus aventuras de codificación!")
print("¯\_( ͡❛ ͜ʖ ͡❛)_/¯")

# %% [markdown]
# organizar mejor el codigo

# %%
#Variables----
cantidad_manzanas = 100 #manzana que tenemos
cantidad_naranjas = 50 #naranja que tenemos

cantidad_de_frutas = cantidad_manzanas + cantidad_naranjas#operaciones de suma-----

cantidad_de_frutas_vendidas=999 #experimentando con numeros grades

frutas_restantes = cantidad_de_frutas - cantidad_de_frutas_vendidas#operaciones de resta 
print("----------(Resultados: )-------------------------")
print("-> Cantidad total de frutas: ", cantidad_de_frutas) #operaciones de suma
print("-> Cantidad de frutas vendidas: ", cantidad_de_frutas_vendidas) #operaciones de resta
print("-> Cantidad de frutas restantes: ", frutas_restantes) #operaciones de resta
print("--------------------------------------------------")

# %% [markdown]
# nuevo challege Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
nombre = "Esteban"# variable de tipo string donde se usa para guardar el nombre de una persona
apellido = "Dido" # variable de tipo string donde se usa para guardar el apellido de una persona   

nombre_completo = nombre + " " + apellido # aquí se concatena el nombre y el apellido para formar el nombre completo
print("----------------------------------")
print(f"Bienvenido: {nombre_completo}, todo listo")# aquí se muestra el nombre completo utilizando una f-string para formatear la salida de manera clara y legible
print("----------------------------------")

# %% [markdown]
# Challenge 🤺 – 15m
#
# 🎯 Objetivo: Practicar división y módulo.
#
# Imagina que estás repartiendo caramelos: solicita al usuario ingresar el total de caramelos y la cantidad de niños, luego calcula cuántos caramelos recibe cada niño usando división entera y cuántos sobran usando módulo, e imprime ambos resultados.

# %%
print("-> Ingrese la cantidad total de caramelos: ")
#carga de datos
total_de_caramelos = int(input("Cuantos caramelos tienes para los niños? "))# aquí se solicita al usuario que ingrese la cantidad total de caramelos, y se convierte esa entrada en un número entero utilizando la función int()
print("-> cuantos niños estan en el cumpleanios: ")# aquí se solicita al usuario que ingrese la cantidad de niños presentes en el cumpleaños, y se convierte esa entrada en un número entero utilizando la función int()
cantidad_de_niños = int(input("-> Cuantos niños hay? "))# aquí se solicita al usuario que ingrese la cantidad de niños presentes en el cumpleaños, y se convierte esa entrada en un número entero utilizando la función int()
#operación de división para repartir los caramelos entre los niños
caramelos_por_niño = total_de_caramelos // cantidad_de_niños
caramelos_que_sobran =  total_de_caramelos % cantidad_de_niños 
#resultados
print("---------------------------------------(Resultados)---------------------------------------------------------")
print(f"todos los caramelos: {total_de_caramelos}")
print(f"los niños son {cantidad_de_niños}")
print(f"-> Cada mita'i recibe {caramelos_por_niño} Ricos caramelos.Y sobran {caramelos_que_sobran} caramelos que no se pueden repartir entre los niños.")
print("------------------------------------------------------------------------------------------------------------")

# %% [markdown]
# Challenge 🤺 - 15m
# Crear una función de un proceso que se les ocurra que tenga varios pasos.
#
# Ejecutar la función 3 veces.

# %%
# lo que se pueda hacer para practicar funciones

def comprar():
    print("-----((  Carrito de compras    ))----- ")# aquí se muestra un mensaje de bienvenida al usuario y se le solicita que ingrese los datos de su compra
    
    nombre_producto = input("¿Qué producto deseas comprar? ")# aquí se solicita al usuario que ingrese el nombre del producto que desea comprar, y se almacena esa entrada en la variable producto
    precioProducto = int(input("¿precio tiene el producto? "))# aquí se solicita al usuario que ingrese el nombre del producto que desea comprar, y se almacena esa entrada en la variable producto
    cantidad = int(input("¿Cuántos productos deseas comprar? "))# aquí se solicita al usuario que ingrese la cantidad de productos que desea comprar, y se convierte esa entrada en un número entero utilizando la función int(), y se almacena en la variable cantidad
    dinero_disponible= int(input("cuanto dinero tienes disponible: "))
    #
    calcular_total=(precioProducto * cantidad) # aquí se realiza una operación de multiplicación entre el producto y la cantidad para calcular el total a pagar, y se almacena en la variable calcular_total
    calcular_iva_total = ((calcular_total * 10)/100)  # aquí se calcula el IVA total multiplicando el total a pagar por 0.19 (que es el porcentaje del IVA), y se almacena en la variable calcular_iva_total
    calcular_precio_total_con_iva = calcular_total + calcular_iva_total # precio mas iva
    calcular_vuelto = dinero_disponible - calcular_precio_total_con_iva # aquí se calcula el vuelto restando el precio total con IVA del dinero disponible, y se almacena en la variable calcular_vuelto

    print("---------------((( Compra realizada ))))-------------------")# aquí se muestra una línea de separación para mejorar la legibilidad de la salida   
    print(f"nombre del producto: {nombre_producto}")# aquí se muestra el nombre del producto utilizando una f-string para formatear la salida de manera clara y legible
    print(f"El total a pagar por {cantidad} {precioProducto}(s) es: {calcular_total} Guaranies")# aquí se muestra el resultado del cálculo utilizando 
    print(f"El IVA es: {calcular_iva_total} Guaranies")# aquí se muestra el resultado del cálculo utilizando una f-string para formatear la salida de manera clara y legible
    print(f"Total a pagar: {calcular_precio_total_con_iva} Guaranies")# aquí se muestra el resultado del cálculo utilizando una f-string para formatear la salida de manera clara y legible
    print(f"Vuelto: {calcular_vuelto} Guaranies")
    print("------Gracias por su compra, vuelva pronto!-----")# aquí se muestra un mensaje de agradecimiento al usuario por su compra
    
# para practicar funciones, se puede crear una función llamada comprar() que simule un proceso de compra en una tienda. La función puede solicitar al usuario que ingrese el nombre del producto que desea comprar, la cantidad, y el dinero disponible. Luego, la función puede realizar cálculos para determinar el total a pagar, el IVA, el precio total con IVA, y el vuelto. Finalmente, la función puede mostrar los resultados de manera clara y legible utilizando f-strings.
comprar()
comprar()
comprar()

# %% [markdown]
# Challenge 🤺 - 25m
#
# Escribir una funcion que represente un sistema de pedidos de comida rapida.
#
# La funcion debe recibir como parametros el nombre del producto y el tamaño del pedido.
#
# Al ejecutarse, debe imprimir en pantalla el detalle del pedido de forma clara y ordenada.
#
# Luego, llamar a la funcion pasando los argumentos correspondientes para simular que un cliente realiza un pedido.

# %%
postres_solicitados = input("¿Qué postres deseas comprar? ")# aquí se solicita al usuario que ingrese los postres que desea solicitar
dietetico= input("¿Deseas que sea dietetico o no? " )# aquí se solicita al usuario que ingrese si desea que el postre sea dietético o no

def procesando_pedido(postre,diet):
        print("-----------------pedido en Curso------------------------------------")
        print(f"-> Procesando pedido para los postres: {postre}, es dietético: {diet}")
        print("🍧 ¡Pedido procesado con éxito! Disfruta de tus postres.")
        print("---------------------Todo Listo para servir-------------------------")
        
procesando_pedido(postres_solicitados,dietetico)

# %% [markdown]
# Challenge 🤺 - 10m
#
# 🎯 Objetivo:
# Practicar variables globales y locales.
#
# Escribir una función calcular_total que reciba el precio de un producto y calcule el total sumando un impuesto global impuesto = 10.
# Usa una variable local total para almacenar el resultado e imprime el total.
# Llama a la función con distintos precios para probar.

# %%
impuesto = 0.1 # porcentaje de impuesto

def calcular_total(precio, cantidad):
    total = precio * cantidad
    total_mas_iVA = total + (total * impuesto)
    
    print  (f"El total a pagar por {cantidad} productos es: {total_mas_iVA} Guaranies")
    
calcular_total(int(input("Ingrese el precio del producto: ")), int(input("Ingrese la cantidad de productos: ")))
calcular_total(int(input("Ingrese el precio del producto: ")), int(input("Ingrese la cantidad de productos: ")))
calcular_total(int(input("Ingrese el precio del producto: ")), int(input("Ingrese la cantidad de productos: ")))
# Out:
# El total a pagar por 1 productos es: 1100.0 Guaranies
