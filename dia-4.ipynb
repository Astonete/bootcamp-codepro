# %% [markdown]
# Olaf — 9:45 a.m.
# Challenge 1 🤺
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario.
#
# Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario..

# %%
#diccionario
persona={}# dicccionario con clave vacia
print(persona)
persona['nombre']=input("Ingresar el nombre")# Ingresa el dato y sin demora,y lo guarda en una clave donde siempre se atesora.
print(persona)
persona['edad']=input("Ingresar el edad")
print(persona)
persona['sexo']=input("Ingresar el sexo")
print(persona)
persona['teléfono']=input("Ingresar el telefono")
print(persona)
persona['email']=input("Ingresar el email")
print(persona)
persona['cedula']=input("Ingresar el cedula")
print(persona)
# Out:
# {'nombre': 'a', 'edad': '', 'sexo': '', 'teléfono': '', 'email': '', 'cedula': ''}
# {'nombre': 'a', 'edad': '3', 'sexo': '', 'teléfono': '', 'email': '', 'cedula': ''}
# {'nombre': 'a', 'edad': '3', 'sexo': '4', 'teléfono': '', 'email': '', 'cedula': ''}
# {'nombre': 'a', 'edad': '3', 'sexo': '4', 'teléfono': '5', 'email': '', 'cedula': ''}
# {'nombre': 'a', 'edad': '3', 'sexo': '4', 'teléfono': '5', 'email': '6', 'cedula': ''}
# {'nombre': 'a', 'edad': '3', 'sexo': '4', 'teléfono': '5', 'email': '6', 'cedula': '7'}

# %% [markdown]
# Olaf — 10:23 a.m.
# Challenge 2 🤺
# Crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# Crear datos nuevos
# Modificar datos
# Eliminar datos

# %%
tarjeta={}#clave:valor

print ("ingrese un numero para acceder a la opcion")
print ("1 para Agregar datos al diccionario")
print ("2 para Modificar ")
print ("3 para eliminar datos")
print ("0 para salir")

opcion=input('ingrese numero')

if(opcion==1):
    clave=input('ingrese el nombre de la clave')
    contenido=input('')
    tarjeta[clave]=contenido
    print(tarjeta)
elif(opcion==2):
    print(f"el valor que desea modificar",tarjeta)
    persona.[]
    contenido=input
    print(tarjeta)
elif(opcion==3):

else:
    print("opcion no valida")

# %% [markdown]
# Challenge 3 🤺
# Crear una agenda de contactos. El usuario puede elegir:
#
# Mostrar los contactos
# Crear contacto
# Modificar datos del contacto

# %%
contacto={}# (juan: numero numero: 1, ana numero 2)


print (contacto)# mostrar

while(True):
    print('1 crear')
    print('2 modificar')
    print('3 eliminar')
    print('0 salir')
    opcion=int(input('ingrese una opcion'))
    
    #crear
    if(opcion==1):
        nombre=input('ingrese nombre') 
        numero=input('ingrese numero')
        contacto[nombre]=numero
        print(contacto)

    # modificar
    elif(opcion==2):
        print(f"contacto")
        nombre=input('ingrese nombre') 
        numero=input('ingrese numero')
        contacto[nombre]=numero
        print(contacto)

    # elimiminar
    elif(opcion==3):
        contacto.pop(input('ingrese nombre para eliminar'))
        print(contacto)
    # salir
    elif(opcion==0):
        print(" hasta la vista baby")
        break
    
    else:
        print(" opcion no valida")
# Out:
# {}
# {'1': '1'}
# {}
