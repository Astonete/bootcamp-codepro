# %% [markdown]
# Olaf — 1:33 p.m.
# Challenge 🤺15 min
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# Atributos de clase: especie.
# Atributos de instancia: nombre & color
# .
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo {nombre} y soy un ave de color {color}".

# %%
class Animales:
    naturaleza='salvaje'
    visto='si'
    
    def __init__(self,nombre,color):
        self.nombre= nombre
        self.color= color
        

camello=Animales("camello","blanco")
narval=Animales("narval","rosa")

print(f"me llamo {camello.nombre} soy de color {camello.color} en estado {camello.naturaleza}")
print(f"me llamo {narval.nombre} soy de color {narval.color} en estado {narval.naturaleza}")
# Out:
# me llamo camello soy de color blanco en estado salvaje
# me llamo narval soy de color rosa en estado salvaje

# %% [markdown]
# Challenge 🤺
# Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.
#
# Ejemplo: "Cuando hablo, digo X".
# Ejemplo: "Cuando me muevo, hago X".

# %%
class Animales:
    tipo='ave'
    
    def __init__(self,clima,peligro,direccion):
        self.clima=clima
        self.peligro=peligro
        self.direccion=direccion

    def migrar_a(clima):
        print(f"esta ave le guasta migrar a {clima}")       
    
    def atacar_a(peligro):
        print(f"atacar a presa  {peligro}")       
    
    def volar_a(direccion):
        print(f"esta ave vuele  a {direccion}")       


aguila = Animales
aguila.migrar_a(input("ingrese el clima que le gusta"),input("presa del ave"),input("direccion a la que vuela"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 20
#      16         print(f"esta ave vuele  a {direccion}")
#      19 aguila = Animales
# ---> 20 aguila.migrar_a(input("ingrese el clima que le gusta"),
#      21                 input("presa del ave"),
#      22                 input("direccion de vuelo"))
#
# TypeError: Animales.migrar_a() takes 1 positional argument but 3 were given

# %% [markdown]
# Olaf — 4:22 p.m.
# Challenge 🤺15 min
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
#
# Observación: Editar las clases hijas para que no se inicialicen.

# %%
class Madre:
    
    def __init__(self,ojos,apellido):
        self.ojos=ojos
    
    


class Hija(Madre):
        
        self.ojos=ojos
        

class Nieta(Madre):

# %% [markdown]
# Olaf — 4:54 p.m.
# Challenge 🤺
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %%
class Personajes:
    
    def __init__(self,nombre,poderes):
        self.nombre=nombre
        self.poderes=poderes
    
    def nombrePersona(nomb,pod):
        print(f'yo me llamo {}') 
class Heroe(Personajes):
    def dialogo(self, frase):
        frase=frase
    print(f" alto ahi rufian {nom}")#nombre
    
class Villano(Personajes):
    def dialogo(self, frase):
        frase=frase
    print(f" Ni siquiera lo Intentes")#nombre
